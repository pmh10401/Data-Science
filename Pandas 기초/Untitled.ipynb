# %% [markdown]
# # 시작
#
# 이 챕터는 다음 데이터셋을 사용하고 있습니다. [Wine Reviews dataset](https://www.kaggle.com/zynicide/wine-reviews).

# %%
import pandas as pd

reviews = pd.read_csv("data/winemag-data-130k-v2.csv", index_col=0) #csv 파일을 읽어오고, 0번 col을 인덱스로 설정합니다.

pd.set_option('max_rows', 5) #기본 출력 row의 수를 5개로 설정하는 것입니다.

# %%
reviews
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# ...        ...                                                ...
# 2604        US  This is a rich, robust Pinot Noir, defining th...
# 2605        US  This Cab wants a few more years to let its int...
#
#                  designation  points  price           province  \
# 0               Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                   Avidagos      87   15.0              Douro
# ...                      ...     ...    ...                ...
# 2604              Los Olivos      90   42.0         California
# 2605  Bell Mountain Vineyard      90   52.0         California
#
#               region_1 region_2    taster_name taster_twitter_handle  \
# 0                 Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1                  NaN      NaN     Roger Voss            @vossroger
# ...                ...      ...            ...                   ...
# 2604       Napa Valley     Napa            NaN                   NaN
# 2605  Alexander Valley   Sonoma            NaN                   NaN
#
#                                                   title         variety  \
# 0                     Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1         Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                 ...             ...
# 2604  Maldonado 2011 Los Olivos Pinot Noir (Napa Val...      Pinot Noir
# 2605  Medlock Ames 2008 Bell Mountain Vineyard Caber...             NaN
#
#                    winery
# 0                 Nicosia
# 1     Quinta dos Avidagos
# ...                   ...
# 2604            Maldonado
# 2605                  NaN
#
# [2606 rows x 13 columns]

# %% [markdown]
# 파이썬에서는 `객체의 속성(attribute)`에 접근함으로써 `객체의 특성(property)`에 접근할 수 있다. 예를 들어, `book` 객체는 `title 속성`을 가질 수 있는데, `book.title`을 호출하는 것을 통해 접근이 가능하다. pandas DataFrame 객체의 row도 동일한 방식으로 접근이 가능하다.
#
# 따라서 `reviews`의 `country 특성(property)`에 접근하기 위해 우리는 아래와 같이 할 수 있다.

# %%
reviews.country
# Out:
# 0          Italy
# 1       Portugal
#           ...
# 2604          US
# 2605          US
# Name: country, Length: 2606, dtype: object

# %% [markdown]
# 파이썬 딕셔너리에서 우리는 인덱싱 연산자인 `[]` 연산자를 이용해서 값(value)에 접근한다. DataFrame 객체의 열에서도 똑같이 `[]`를 이용할 수 있다.

# %%
reviews['country']
# Out:
# 0          Italy
# 1       Portugal
#           ...
# 2604          US
# 2605          US
# Name: country, Length: 2606, dtype: object

# %% [markdown]
# 이것이 DataFrame에서 Series를 선택하는 2가지 방법이다.
#
# 두 방법 모두 특별히 차이는 없지만, `[]`연산자는 변수를 이용해서 더 자유롭게 인덱싱을 할 수 있다는 장점이 있다.
#
# 예를 들어 `item number`라는 column이 있을 때, 첫번째 방법인 `.`은 해당 column을 접근할 수 없으나, 두번째 방법은 `review['item number']`로 접근할 수 있다.
#
# 2차원 배열을 다루듯, `[]`를 한번 더 사용하면 엔트리의 단일 값으로  접근할 수 있다.

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# # Indexing
#
# Pandas는 2가지 indexing 방법이 있다. `iloc`과 `loc`이다. `iloc`은 index의 번호를 기반으로 한다. 쉽게 index location이라고 기억하면 된다. `loc`은 라벨 기준 접근 방법이다.
#
# ## - iloc

# %%
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %% [markdown]
# 위의 셀은 0번 row에 접근한 결과이다.

# %% [markdown]
# 파이썬과 달리, `loc`과 `iloc`은 row를 먼저 쓰고, column을 나중에 쓴다.
#
# 만약, 0번 column (country) 전체를 접근하고 싶으면 다음과 같이 하면 된다.

# %%
reviews.iloc[:,0]
# Out:
# 0          Italy
# 1       Portugal
#           ...
# 2604          US
# 2605          US
# Name: country, Length: 2606, dtype: object

# %% [markdown]
# `:`은 everyting을 의미한다. 즉, 모든 row의 0번 column을 접근한 것이다.

# %%
reviews.iloc[:3,0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %% [markdown]
# 처음 row부터 3번 row 전 까지 접근하는 방법이다.
#
# 즉, `reviews.iloc[시작 row : 희망 하는 row 번호 +1 ,0]`로 접근하면 된다. 이건 파이썬의 list 접근방법과 동일하다. 단지 row와 column의 순서가 다를 뿐이다.

# %% [markdown]
# ## - loc
#
# `loc`를 라벨 기준 접근 방법이다.

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %% [markdown]
# 0번 row의 country를 접근하였다.

# %%
reviews.loc[: , 'country']
# Out:
# 0          Italy
# 1       Portugal
#           ...
# 2604          US
# 2605          US
# Name: country, Length: 2606, dtype: object

# %% [markdown]
# country라는 columns를 접근하는 방법이다. 즉, 라벨을 사용한다는 점만 다른 것이다.
#
# `그럼 loc은 언제 사용하는 것일까?`
#
# DataFrame이 크면 번호로 인덱싱을 하는 것이 쉽지 않다. 이 때 loc을 사용하는 것이 편할 것이다.

# %% [markdown]
# ## loc와 iloc의 차이점 및 주의점
#
# `loc`과 `iloc` 중 하나를 고를 때 `유의할만한 사항`이 있는데, 이는 `두 방법이 약간 다른 인덱싱 방식을 사용`한다는 것이다.
#
# `iloc`은 `첫번째 요소가 포함되고 마지막 요소는 제외`되는 Python stdlib 인덱싱 방식을 사용한다.
#
# 따라서 0:10은 0 ~ 9를 선택한다. 반면 `loc`은 `마지막 요소를 포함`하므로 0:10은 0 ~ 10을 선택한다.
#
# ### 왜 두 방식은 서로 다를까?
#
# loc은 문자열같은 stdlib 타입을 인덱싱할 수 있다.
#
# 예를 들어 'Apple' : 'Potato'는 `'Apple'부터 'Potato'까지`를 가리키는 것이 `'Apple'부터 'Potato'이전 까지`의 인덱스 를 가리키는 것보다 더 편리하기 때문이다.
#
# `이는 DataFrame의 인덱스가 단순한 숫자 목록일 때 혼란을 줄 수 있다.`
#
# 예를 들어, 0,...,1000 row를 접근한다고 해보자. iloc[0:1000]의 경우 1000개를 돌려준다. 반면에 loc[0:1000]은 1001개를 돌려준다! 즉, loc[0:999]라고 써야지만 1000개가 반환된다.
#
# 개인적으로 loc가 직관적이라고 생각한다. 어디부터 어디까지라고 읽어지기 때문에 loc을 좋아한다.

# %% [markdown]
# # Manipulating the index
#
# Label-based selection(`loc`)은 index가 레이블일 때 매우 효과적이다.
#
# set_index() 메서드는 인덱스를 설정할 수 있다. 아래에선 title 필드를 인덱스로 지정한다.

# %%
reviews.set_index("title")
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)        US
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...        US
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)  This is a rich, robust Pinot Noir, defining th...
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...  This Cab wants a few more years to let its int...
#
#                                                                designation  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                             Vulkà Bianco
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                     Avidagos
# ...                                                                    ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)              Los Olivos
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...  Bell Mountain Vineyard
#
#                                                     points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                       87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)           87   15.0
# ...                                                    ...    ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)      90   42.0
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...      90   52.0
#
#                                                              province  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Sicily & Sardinia
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                   Douro
# ...                                                               ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)         California
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...         California
#
#                                                             region_1 region_2  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                               Etna      NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                    NaN      NaN
# ...                                                              ...      ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)       Napa Valley     Napa
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...  Alexander Valley   Sonoma
#
#                                                       taster_name  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Kerin O’Keefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)          Roger Voss
# ...                                                           ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)            NaN
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...            NaN
#
#                                                    taster_twitter_handle  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                           @kerinokeefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                 @vossroger
# ...                                                                  ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)                   NaN
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...                   NaN
#
#                                                            variety  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      White Blend
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portuguese Red
# ...                                                            ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)      Pinot Noir
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...             NaN
#
#                                                                  winery
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                               Nicosia
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Quinta dos Avidagos
# ...                                                                 ...
# Maldonado 2011 Los Olivos Pinot Noir (Napa Valley)            Maldonado
# Medlock Ames 2008 Bell Mountain Vineyard Cabern...                  NaN
#
# [2606 rows x 12 columns]

# %% [markdown]
# 위와 같이 index를 정해두면 `iloc`를 이용하여 원하는 row를 접근하기 쉽지 않다.

# %% [markdown]
# # 조건문을 이용한 selection
#
# country가 Italy인 row들을 접근하고 싶다고 가정해보자.

# %%
reviews.country == 'Italy'
# Out:
# 0        True
# 1       False
#         ...
# 2604    False
# 2605    False
# Name: country, Length: 2606, dtype: bool

# %% [markdown]
# 0번 row에서 True가 반환된 것을 확인할 수 있다.
#
# 이 True/False 값을 loc에 대입하면 원하는 row들만 얻어올수 있다.

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#      country                                        description   designation  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6      Italy  Here's a bright, informal red that opens with ...       Belsito
# ...      ...                                                ...           ...
# 2591   Italy  This traditionally styled Barolo has a classic...        Bussia
# 2592   Italy  This shows enticing aromas of mint, spice and ...    Castellero
#
#       points  price           province  region_1 region_2    taster_name  \
# 0         87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 6         87   16.0  Sicily & Sardinia  Vittoria      NaN  Kerin O’Keefe
# ...      ...    ...                ...       ...      ...            ...
# 2591      90   92.0           Piedmont    Barolo      NaN  Kerin O’Keefe
# 2592      90   82.0           Piedmont    Barolo      NaN  Kerin O’Keefe
#
#      taster_twitter_handle                                             title  \
# 0             @kerinokeefe                 Nicosia 2013 Vulkà Bianco  (Etna)
# 6             @kerinokeefe  Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# ...                    ...                                               ...
# 2591          @kerinokeefe             Barale Fratelli 2009 Bussia  (Barolo)
# 2592          @kerinokeefe         Barale Fratelli 2009 Castellero  (Barolo)
#
#           variety           winery
# 0     White Blend          Nicosia
# 6        Frappato  Terre di Giurfo
# ...           ...              ...
# 2591     Nebbiolo  Barale Fratelli
# 2592     Nebbiolo  Barale Fratelli
#
# [470 rows x 13 columns]

# %%
reviews.loc[reviews['country'] == 'Italy']
# Out:
#      country                                        description   designation  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6      Italy  Here's a bright, informal red that opens with ...       Belsito
# ...      ...                                                ...           ...
# 2591   Italy  This traditionally styled Barolo has a classic...        Bussia
# 2592   Italy  This shows enticing aromas of mint, spice and ...    Castellero
#
#       points  price           province  region_1 region_2    taster_name  \
# 0         87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 6         87   16.0  Sicily & Sardinia  Vittoria      NaN  Kerin O’Keefe
# ...      ...    ...                ...       ...      ...            ...
# 2591      90   92.0           Piedmont    Barolo      NaN  Kerin O’Keefe
# 2592      90   82.0           Piedmont    Barolo      NaN  Kerin O’Keefe
#
#      taster_twitter_handle                                             title  \
# 0             @kerinokeefe                 Nicosia 2013 Vulkà Bianco  (Etna)
# 6             @kerinokeefe  Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# ...                    ...                                               ...
# 2591          @kerinokeefe             Barale Fratelli 2009 Bussia  (Barolo)
# 2592          @kerinokeefe         Barale Fratelli 2009 Castellero  (Barolo)
#
#           variety           winery
# 0     White Blend          Nicosia
# 6        Frappato  Terre di Giurfo
# ...           ...              ...
# 2591     Nebbiolo  Barale Fratelli
# 2592     Nebbiolo  Barale Fratelli
#
# [470 rows x 13 columns]

# %%
reviews.iloc[reviews['country'] == 'Italy']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-21-8067368a37c6> in <module>
# ----> 1 reviews.iloc[reviews['country'] == 'Italy']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2121
#    2122         if com.is_bool_indexer(key):
# -> 2123             self._validate_key(key, axis)
#    2124             return self._getbool_axis(key, axis=axis)
#    2125
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1978                 if key.index.inferred_type == "integer":
#    1979                     raise NotImplementedError(
# -> 1980                         "iLocation based boolean "
#    1981                         "indexing on an integer type "
#    1982                         "is not available"
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %% [markdown]
# 위에서 확인할 수 있듯이 iloc을 사용할 시 에러가 발생한다. 그래서 loc가 좋다는 것이다.

# %% [markdown]
# ## &와 |
#
# 2개 이상의 조건을 적용할 때에는 `&`와 `|`를 사용하면 된다.

# %% [markdown]
# 예를 들어, 'US' 자료 중 points가 90 이상인 데이터를 얻고 싶다면 다음과 같이 하면 된다.

# %%
reviews.loc[(reviews.country == 'US') & (reviews.points >= 90)]
# Out:
#      country                                        description  \
# 121       US  The vineyard is one of the better Chardonnay s...
# 122       US  Defines Rockpile Zinfandel in intensity of fru...
# ...      ...                                                ...
# 2604      US  This is a rich, robust Pinot Noir, defining th...
# 2605      US  This Cab wants a few more years to let its int...
#
#                      designation  points  price    province          region_1  \
# 121         Stuhlmuller Vineyard      92   36.0  California  Alexander Valley
# 122   Rockpile Cemetary Vineyard      92   39.0  California          Rockpile
# ...                          ...     ...    ...         ...               ...
# 2604                  Los Olivos      90   42.0  California       Napa Valley
# 2605      Bell Mountain Vineyard      90   52.0  California  Alexander Valley
#
#      region_2 taster_name taster_twitter_handle  \
# 121    Sonoma         NaN                   NaN
# 122    Sonoma         NaN                   NaN
# ...       ...         ...                   ...
# 2604     Napa         NaN                   NaN
# 2605   Sonoma         NaN                   NaN
#
#                                                   title     variety     winery
# 121   Matrix 2007 Stuhlmuller Vineyard Chardonnay (A...  Chardonnay     Matrix
# 122   Mauritson 2007 Rockpile Cemetary Vineyard Zinf...   Zinfandel  Mauritson
# ...                                                 ...         ...        ...
# 2604  Maldonado 2011 Los Olivos Pinot Noir (Napa Val...  Pinot Noir  Maldonado
# 2605  Medlock Ames 2008 Bell Mountain Vineyard Caber...         NaN        NaN
#
# [407 rows x 13 columns]

# %% [markdown]
# 예를 들어, 'Italy'와 'US'를 불러오고 싶다면 다음과 같이하면 된다.

# %%
reviews.loc[(reviews.country == 'ltaly') | (reviews.country == 'US')]
# Out:
#      country                                        description  \
# 2         US  Tart and snappy, the flavors of lime flesh and...
# 3         US  Pineapple rind, lemon pith and orange blossom ...
# ...      ...                                                ...
# 2604      US  This is a rich, robust Pinot Noir, defining th...
# 2605      US  This Cab wants a few more years to let its int...
#
#                  designation  points  price    province             region_1  \
# 2                        NaN      87   14.0      Oregon    Willamette Valley
# 3       Reserve Late Harvest      87   13.0    Michigan  Lake Michigan Shore
# ...                      ...     ...    ...         ...                  ...
# 2604              Los Olivos      90   42.0  California          Napa Valley
# 2605  Bell Mountain Vineyard      90   52.0  California     Alexander Valley
#
#                region_2         taster_name taster_twitter_handle  \
# 2     Willamette Valley        Paul Gregutt           @paulgwine
# 3                   NaN  Alexander Peartree                   NaN
# ...                 ...                 ...                   ...
# 2604               Napa                 NaN                   NaN
# 2605             Sonoma                 NaN                   NaN
#
#                                                   title     variety  \
# 2         Rainstorm 2013 Pinot Gris (Willamette Valley)  Pinot Gris
# 3     St. Julian 2013 Reserve Late Harvest Riesling ...    Riesling
# ...                                                 ...         ...
# 2604  Maldonado 2011 Los Olivos Pinot Noir (Napa Val...  Pinot Noir
# 2605  Medlock Ames 2008 Bell Mountain Vineyard Caber...         NaN
#
#           winery
# 2      Rainstorm
# 3     St. Julian
# ...          ...
# 2604   Maldonado
# 2605         NaN
#
# [1033 rows x 13 columns]

# %% [markdown]
# 이렇게 &를 이용할 때, 원하는 나라들이 많다면 상당히 사용하기 힘들 것이다. 그렇기 때문에 Pandas는 `isin`을 제공한다.
#
# `isin`은 `is in the list`를 의미한다.

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#      country                                        description   designation  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6      Italy  Here's a bright, informal red that opens with ...       Belsito
# ...      ...                                                ...           ...
# 2591   Italy  This traditionally styled Barolo has a classic...        Bussia
# 2592   Italy  This shows enticing aromas of mint, spice and ...    Castellero
#
#       points  price           province  region_1 region_2    taster_name  \
# 0         87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 6         87   16.0  Sicily & Sardinia  Vittoria      NaN  Kerin O’Keefe
# ...      ...    ...                ...       ...      ...            ...
# 2591      90   92.0           Piedmont    Barolo      NaN  Kerin O’Keefe
# 2592      90   82.0           Piedmont    Barolo      NaN  Kerin O’Keefe
#
#      taster_twitter_handle                                             title  \
# 0             @kerinokeefe                 Nicosia 2013 Vulkà Bianco  (Etna)
# 6             @kerinokeefe  Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# ...                    ...                                               ...
# 2591          @kerinokeefe             Barale Fratelli 2009 Bussia  (Barolo)
# 2592          @kerinokeefe         Barale Fratelli 2009 Castellero  (Barolo)
#
#           variety           winery
# 0     White Blend          Nicosia
# 6        Frappato  Terre di Giurfo
# ...           ...              ...
# 2591     Nebbiolo  Barale Fratelli
# 2592     Nebbiolo  Barale Fratelli
#
# [904 rows x 13 columns]

# %% [markdown]
# ## Null 값 다루기
#
# 데이터를 분석할 때 가장 먼저 Missing value를 확인하게 된다. 이 때, 유용한 기능이 `notnull`과 `isnull`이다.
#
# `notnull`은 null이 아닌 것을 찾는 것이다.
#
# 아래의 예제는 Column `price`에서 Null 값이 아닌 값들만 불러오는 것이다.

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#        country                                        description  \
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# 2           US  Tart and snappy, the flavors of lime flesh and...
# ...        ...                                                ...
# 2604        US  This is a rich, robust Pinot Noir, defining th...
# 2605        US  This Cab wants a few more years to let its int...
#
#                  designation  points  price    province           region_1  \
# 1                   Avidagos      87   15.0       Douro                NaN
# 2                        NaN      87   14.0      Oregon  Willamette Valley
# ...                      ...     ...    ...         ...                ...
# 2604              Los Olivos      90   42.0  California        Napa Valley
# 2605  Bell Mountain Vineyard      90   52.0  California   Alexander Valley
#
#                region_2   taster_name taster_twitter_handle  \
# 1                   NaN    Roger Voss            @vossroger
# 2     Willamette Valley  Paul Gregutt           @paulgwine
# ...                 ...           ...                   ...
# 2604               Napa           NaN                   NaN
# 2605             Sonoma           NaN                   NaN
#
#                                                   title         variety  \
# 1         Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2         Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# ...                                                 ...             ...
# 2604  Maldonado 2011 Los Olivos Pinot Noir (Napa Val...      Pinot Noir
# 2605  Medlock Ames 2008 Bell Mountain Vineyard Caber...             NaN
#
#                    winery
# 1     Quinta dos Avidagos
# 2               Rainstorm
# ...                   ...
# 2604            Maldonado
# 2605                  NaN
#
# [2441 rows x 13 columns]

# %% [markdown]
# 이번엔 Null 값들만 불러와 보자.

# %%
reviews.loc[reviews.price.isnull()]
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 13      Italy  This is dominated by oak and oak-driven aromas...
# ...       ...                                                ...
# 2588  Austria  This is a serious wine, despite the ripe fruit...
# 2595  Austria  Crisp, clean, mineral wine, with hints of a mo...
#
#        designation  points  price           province region_1 region_2  \
# 0     Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 13           Rosso      87    NaN  Sicily & Sardinia     Etna      NaN
# ...            ...     ...    ...                ...      ...      ...
# 2588    Steinbügel      90    NaN   Niederösterreich      NaN      NaN
# 2595        Zöbing      90    NaN            Kamptal      NaN      NaN
#
#         taster_name taster_twitter_handle  \
# 0     Kerin O’Keefe          @kerinokeefe
# 13    Kerin O’Keefe          @kerinokeefe
# ...             ...                   ...
# 2588     Roger Voss            @vossroger
# 2595     Roger Voss            @vossroger
#
#                                                   title            variety  \
# 0                     Nicosia 2013 Vulkà Bianco  (Etna)        White Blend
# 13               Masseria Setteporte 2012 Rosso  (Etna)  Nerello Mascalese
# ...                                                 ...                ...
# 2588  Graf Hardegg 2010 Steinbügel Grüner Veltliner ...   Grüner Veltliner
# 2595              Hirsch 2012 Zöbing Riesling (Kamptal)           Riesling
#
#                    winery
# 0                 Nicosia
# 13    Masseria Setteporte
# ...                   ...
# 2588         Graf Hardegg
# 2595               Hirsch
#
# [165 rows x 13 columns]

# %% [markdown]
# ## 데이터 입력
#
# 데이터를 입력하는 방법은 매우 쉽다.
#
# 예제로 새로운 column을 만들어 데이터를 입력해보자.

# %%
reviews['critic'] = 'everyone'
reviews
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# ...        ...                                                ...
# 2604        US  This is a rich, robust Pinot Noir, defining th...
# 2605        US  This Cab wants a few more years to let its int...
#
#                  designation  points  price           province  \
# 0               Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                   Avidagos      87   15.0              Douro
# ...                      ...     ...    ...                ...
# 2604              Los Olivos      90   42.0         California
# 2605  Bell Mountain Vineyard      90   52.0         California
#
#               region_1 region_2    taster_name taster_twitter_handle  \
# 0                 Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1                  NaN      NaN     Roger Voss            @vossroger
# ...                ...      ...            ...                   ...
# 2604       Napa Valley     Napa            NaN                   NaN
# 2605  Alexander Valley   Sonoma            NaN                   NaN
#
#                                                   title         variety  \
# 0                     Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1         Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                 ...             ...
# 2604  Maldonado 2011 Los Olivos Pinot Noir (Napa Val...      Pinot Noir
# 2605  Medlock Ames 2008 Bell Mountain Vineyard Caber...             NaN
#
#                    winery    critic
# 0                 Nicosia  everyone
# 1     Quinta dos Avidagos  everyone
# ...                   ...       ...
# 2604            Maldonado  everyone
# 2605                  NaN  everyone
#
# [2606 rows x 14 columns]

# %% [markdown]
# `critic`라는 column이 추가되고 모든 값이 `everyone`으로 입력되어 있다.

# %% [markdown]
# 이번에는 반복문을 이용해서 입력해보자.

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# ...        ...                                                ...
# 2604        US  This is a rich, robust Pinot Noir, defining th...
# 2605        US  This Cab wants a few more years to let its int...
#
#                  designation  points  price           province  \
# 0               Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                   Avidagos      87   15.0              Douro
# ...                      ...     ...    ...                ...
# 2604              Los Olivos      90   42.0         California
# 2605  Bell Mountain Vineyard      90   52.0         California
#
#               region_1 region_2    taster_name taster_twitter_handle  \
# 0                 Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1                  NaN      NaN     Roger Voss            @vossroger
# ...                ...      ...            ...                   ...
# 2604       Napa Valley     Napa            NaN                   NaN
# 2605  Alexander Valley   Sonoma            NaN                   NaN
#
#                                                   title         variety  \
# 0                     Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1         Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                 ...             ...
# 2604  Maldonado 2011 Los Olivos Pinot Noir (Napa Val...      Pinot Noir
# 2605  Medlock Ames 2008 Bell Mountain Vineyard Caber...             NaN
#
#                    winery    critic  index_backwards
# 0                 Nicosia  everyone             2606
# 1     Quinta dos Avidagos  everyone             2605
# ...                   ...       ...              ...
# 2604            Maldonado  everyone                2
# 2605                  NaN  everyone                1
#
# [2606 rows x 15 columns]
